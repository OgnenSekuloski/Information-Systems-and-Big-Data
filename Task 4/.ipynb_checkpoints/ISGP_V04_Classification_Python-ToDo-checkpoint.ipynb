# %% [markdown]
# # Classification with SikitLearn
#
# The task is to predict the price of a mobile phone given the charatersitics.
# <br> The pediction is not the exact price, but the price range - 0, 1, 2, 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1. Load the Data
# <hr>
# The dataset is given in the folder with the excercise - it is a CSV file.
# <br>Use read CSV function - pd.read_csv('data_mobile.csv')

# %%
dataset = pd.read_csv('data_mobile.csv')
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Separete the feature vectors in "X", and the class in "y".
# The last column in the dataframe is the class - "price_range" -
# - example y = df[["price_range"]]
# - you can use Pandas drop() method to selet all except "price_range" column

# %%
# select the target class column into a data-frame - y = df["price_range"]
y = dataset["price_range"]
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
# Using drop() method to selet all except "price_range" column
X = dataset.drop('price_range',axis=1)
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Print the shape of X and y

# %%
xshape = X.shape
yshape = y.shape

print(xshape)
print(yshape)
# Out:
# (2000, 20)
# (2000,)

# %% [markdown]
# ## 2. Classification
# <hr>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### 2.1 Train Test Split
#
# Divide the dataset so that the last 200 samples are test, the rest are train. Use variables:
# - X_train - training data - feature vectors
# - X_test - test data - feature vectors
# - y_train - train labels
# - y_test - test labels
#
# Hint:
# - example:  X_train, X_test = X[...], X[...]

# %%
X_train, X_test = X[:-200], X[-200:]
y_train, y_test = y[:-200], y[-200:]

# %% [markdown]
# ### print the shape for all
# - X_train
# - X_test
# - y_train
# - y_test

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1800, 20)
# (200, 20)
# (1800,)
# (200,)

# %%
# with this code you get the class values - the output should be:  [1, 2, 3, 0]
y_train.unique()
# Out:
# array([1, 2, 3, 0], dtype=int64)

# %% [markdown]
# ### Using matplotlib, plot the dataset in a scatter plot with 2 features: "clock_speed" and "ram"
#
# Comment the plot - results:

# %%
ax = plt.subplot(1, 1, 1)
ax.set_title("Input data")

# Plot the training points
ax.scatter(
   X_train["clock_speed"],
   X_train["ram"],
   c=y_train,
   edgecolors="k",
)
ax.set_xlabel("clock_speed")
ax.set_ylabel("ram")
ax.legend
# Out:
# <bound method Axes.legend of <Axes: title={'center': 'Input data'}, xlabel='clock_speed', ylabel='ram'>>

# %% [markdown]
# The different colours represent the 4 different price range classes. The correlation between these parameters is that if both the clock speed and the ram rise, than they're positively correlated.

# %% [markdown]
# The different coulours represent the 4 different price range classes. If clock speed and RAM raise simultaneously, they're positively corelated.

# %% [markdown]
# ### 2.2 Training Classifiers

# %% [markdown]
# #### 2.2.1 Decision Tree Classifier
#
# - train a model with "random_state=1"
# - make predictions on the test set and print them
# - Calculate the accuracy and print it (use the "score" function)

# %%
# create Decistion Tree classifier
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion = 'entropy', random_state = 1)

# Train the models
dt.fit(X_train,y_train)

# Make predictions using the testing set
y_pred_dt = dt.predict(X_test)
y_pred_dt
# Out:
# array([0, 1, 3, 3, 1, 1, 1, 0, 0, 1, 0, 1, 0, 0, 1, 3, 3, 2, 0, 1, 0, 3,
#        1, 2, 2, 1, 2, 3, 3, 0, 0, 1, 2, 2, 2, 1, 2, 1, 0, 2, 3, 1, 0, 3,
#        1, 3, 0, 0, 3, 2, 0, 3, 0, 0, 0, 0, 3, 3, 2, 0, 0, 0, 0, 3, 0, 2,
#        3, 2, 3, 3, 3, 2, 1, 0, 2, 1, 0, 1, 1, 0, 2, 1, 0, 0, 3, 0, 1, 2,
#        0, 3, 1, 0, 0, 2, 0, 2, 0, 3, 2, 1, 1, 2, 3, 2, 3, 0, 1, 2, 2, 1,
#        3, 0, 1, 0, 0, 2, 1, 0, 2, 0, 3, 1, 0, 2, 1, 2, 1, 3, 0, 2, 3, 1,
#        1, 1, 2, 1, 3, 2, 2, 2, 2, 3, 1, 0, 0, 0, 1, 2, 1, 3, 1, 0, 1, 3,
#        0, 3, 0, 3, 2, 1, 3, 0, 1, 1, 1, 0, 3, 0, 1, 2, 2, 0, 0, 3, 1, 3,
#        0, 2, 1, 1, 1, 1, 2, 2, 1, 3, 1, 0, 1, 1, 0, 3, 1, 3, 3, 0, 2, 3,
#        0, 3], dtype=int64)

# %%
#print the accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: ', accuracy)
# Out:
# Accuracy:  0.86

# %% [markdown]
# #### 2.2.2 K-Nearest Neighbors Classifier
# - train a model with "3" nearest neighbours
# - make predictions on the test set and print them
# - Calculate the accuracy and print it (use the "score" function)
#
# If you get an Error- AttributeError: 'Flags' object has no attribute 'c_contiguous'
# - Use "X_test.values" instead of "X_test".... example:  "knn_score = knn.score(X_test.values, y_test)"

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(3)
KNN.fit(X_train, y_train)
y_pred_knn = clf.predict(X_test)
print(y_pred_knn)
KNN_score = KNN.score(X_test, y_test)
print("Accuracy: ", KNN_score)
# Out:
# [0 1 3 3 1 1 1 0 0 1 0 1 0 0 1 3 3 2 0 1 0 3 1 2 2 1 2 3 3 0 0 1 2 2 2 1 2
#  1 0 2 3 1 0 3 1 3 0 0 3 2 0 3 0 0 0 0 3 3 2 0 0 0 0 3 0 2 3 2 3 3 3 2 1 0
#  2 1 0 1 1 0 2 1 0 0 3 0 1 2 0 3 1 0 0 2 0 2 0 3 2 1 1 2 3 2 3 0 1 2 2 1 3
#  0 1 0 0 2 1 0 2 0 3 1 0 2 1 2 1 3 0 2 3 1 1 1 2 1 3 2 2 2 2 3 1 0 0 0 1 2
#  1 3 1 0 1 3 0 3 0 3 2 1 3 0 1 1 1 0 3 0 1 2 2 0 0 3 1 3 0 2 1 1 1 1 2 2 1
#  3 1 0 1 1 0 3 1 3 3 0 2 3 0 3]
# Accuracy:  0.915

# %% [markdown]
# #### 2.2.3 Support Vector Machine Classifier
#
# - train a model with default parameters
# - make predictions on the test set and print them
# - Calculate the accuracy and print it (use the "score" function)

# %%
from sklearn.svm import SVC
SVM = SVC()
SVM.fit(X_train, y_train)
y_pred_SVM = clf.predict(X_test)
print(y_pred_SVM)
SVM_score = SVM.score(X_test, y_test)
print("Accuracy: ", SVM_score)
# Out:
# [0 1 3 3 1 1 1 0 0 1 0 1 0 0 1 3 3 2 0 1 0 3 1 2 2 1 2 3 3 0 0 1 2 2 2 1 2
#  1 0 2 3 1 0 3 1 3 0 0 3 2 0 3 0 0 0 0 3 3 2 0 0 0 0 3 0 2 3 2 3 3 3 2 1 0
#  2 1 0 1 1 0 2 1 0 0 3 0 1 2 0 3 1 0 0 2 0 2 0 3 2 1 1 2 3 2 3 0 1 2 2 1 3
#  0 1 0 0 2 1 0 2 0 3 1 0 2 1 2 1 3 0 2 3 1 1 1 2 1 3 2 2 2 2 3 1 0 0 0 1 2
#  1 3 1 0 1 3 0 3 0 3 2 1 3 0 1 1 1 0 3 0 1 2 2 0 0 3 1 3 0 2 1 1 1 1 2 2 1
#  3 1 0 1 1 0 3 1 3 3 0 2 3 0 3]
# Accuracy:  0.96

# %% [markdown]
# ### 2.3 Confusion Matrix & Classification Report

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
def plot_cm(y_true, y_pred, cmap="Blues", figsize=(4, 4)):
    """
    Plot confusion matrix heatmap.

    Parameters:
        y_true (array-like): True labels.
        y_pred (array-like): Predicted labels.
        cmap (str, optional): Colormap for the heatmap. Defaults to 'Blues'.
    """
    cm = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(
        conf_mat=cm,
        show_absolute=True,
        show_normed=True,
        colorbar=True,
        cmap=cmap,
        figsize=figsize,
    )
    plt.show()

# %% [markdown]
# #### 2.3.1 KNN
# - print the Confusion Matrix - both with the "plot_cm" function, and also the standard one ("confusion_matrix(y_test, y_pred_knn)")
# - print the classificaiton report

# %%
# print classification_report
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        63
#            1       0.80      0.90      0.85        49
#            2       0.79      0.79      0.79        42
#            3       0.89      0.85      0.87        46
#
#     accuracy                           0.86       200
#    macro avg       0.86      0.86      0.85       200
# weighted avg       0.86      0.86      0.86       200

# %%
#standard confusion matrix
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# [[56  7  0  0]
#  [ 3 44  2  0]
#  [ 0  4 33  5]
#  [ 0  0  7 39]]

# %%
#confusion matrix using the - plot_cm(y_test, y_pred_knn)
plot_cm(y_test, y_pred_knn)

# %% [markdown]
# #### 2.3.2 Decision Tree
# - print the Confusion Matrix - both with the "plot_cm" function, and also the standard one ("confusion_matrix(y_test, y_pred_knn)")
# - print the classificaiton report

# %%
# print classification_report
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        63
#            1       0.80      0.90      0.85        49
#            2       0.79      0.79      0.79        42
#            3       0.89      0.85      0.87        46
#
#     accuracy                           0.86       200
#    macro avg       0.86      0.86      0.85       200
# weighted avg       0.86      0.86      0.86       200

# %%
#standard confusion matrix
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# [[56  7  0  0]
#  [ 3 44  2  0]
#  [ 0  4 33  5]
#  [ 0  0  7 39]]

# %%
#confusion matrix using the - plot_cm(y_test, y_pred_knn)
plot_cm(y_test, y_pred_dt)

# %% [markdown]
# #### 2.3.3 SVM
# - print the Confusion Matrix - both with the "plot_cm" function, and also the standard one ("confusion_matrix(y_test, y_pred_knn)")
# - print the classificaiton report

# %%
# print classification_report
print(classification_report(y_test, y_pred_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92        63
#            1       0.80      0.90      0.85        49
#            2       0.79      0.79      0.79        42
#            3       0.89      0.85      0.87        46
#
#     accuracy                           0.86       200
#    macro avg       0.86      0.86      0.85       200
# weighted avg       0.86      0.86      0.86       200

# %%
#standard confusion matrix
print(confusion_matrix(y_test, y_pred_SVM))
# Out:
# [[56  7  0  0]
#  [ 3 44  2  0]
#  [ 0  4 33  5]
#  [ 0  0  7 39]]

# %%
#confusion matrix using the - plot_cm(y_test, y_pred_knn)
plot_cm(y_test, y_pred_SVM)

# %% [markdown]
# ## 2.4 Random forest
#
# - train a Random Forest model with "random_state=1"
# - make predictions on the test set and print them
# - Calculate the accuracy and print it (use the "score" function)
# - print the Confusion Matrix - both with the "plot_cm" function, and also the standard one ("confusion_matrix(y_test, y_pred_knn)")
# - print the classificaiton report

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state = 1)
RF.fit(X_train,y_train)

y_pred_rf = RF.predict(X_test)
print(y_pred_rf)

rf_score = RF.score(X_test, y_test)
print("Accuracy: ", rf_score)
# Out:
# [0 1 3 3 0 2 0 1 0 1 0 1 0 0 1 3 3 1 0 2 0 3 1 2 2 1 2 3 3 0 0 1 2 2 2 1 2
#  1 0 2 3 1 0 3 1 3 0 0 3 3 0 3 0 0 0 0 3 3 2 0 0 0 0 3 0 2 3 2 3 3 3 2 1 0
#  2 0 0 1 2 0 2 1 0 0 3 0 1 2 0 3 1 0 0 3 0 2 0 3 3 0 1 1 2 2 3 0 1 3 3 1 3
#  0 2 0 0 2 1 0 2 0 3 2 0 2 1 2 1 3 0 2 3 1 1 1 2 1 3 2 2 2 2 3 0 0 1 0 1 2
#  1 2 1 0 1 3 0 3 0 3 2 1 2 1 2 1 1 0 2 0 0 2 1 1 0 3 1 3 0 2 1 1 1 1 2 2 1
#  3 1 0 1 2 0 3 0 3 3 0 2 3 0 3]
# Accuracy:  0.89

# %% [markdown]
# ## 3. Evalution - Random split
# <hr>

# %% [markdown]
# ### 3.1 Train-test set - Random split
#
# Use "train_test_split" function and divide the data into 75% train and 25% test randomly (shuffle = True). Use random_state=1

# %%
from sklearn.model_selection import train_test_split
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X, y, random_state = 1, train_size = 0.75, shuffle=True)

# %% [markdown]
# ### print the shape for all¶
# * X_train
# * X_test
# * y_train
# * y_test

# %%
print(f"X_train shape: {X_train_new.shape}\nX_train type: {type(X_train_new)}\n")
print(f"y_train shape: {y_train_new.shape}\ny_train type: {type(y_train_new)}\n")
print(f"X_test shape: {X_test_new.shape}\nX_test type: {type(X_test_new)}\n")
print(f"y_test shape: {y_test_new.shape}\ny_test type: {type(y_test_new)}")
# Out:
# X_train shape: (1500, 20)
# X_train type: <class 'pandas.core.frame.DataFrame'>
#
# y_train shape: (1500,)
# y_train type: <class 'pandas.core.series.Series'>
#
# X_test shape: (500, 20)
# X_test type: <class 'pandas.core.frame.DataFrame'>
#
# y_test shape: (500,)
# y_test type: <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Train and compare the accuracy for:
# - Decision Tree
# - KNN
# - SVM
# - Random Forest
#
# Present the accuracy in a Table and also in Bar Chart - you have the code below.

# %%
# Create KNN
KNN_new = KNeighborsClassifier(3)
KNN_new.fit(X_train_new, y_train_new)

# create Decistion Tree
dt_new = DecisionTreeClassifier(max_depth = 5, random_state = 1)
dt_new.fit(X_train_new, y_train_new)

# create SVM
SVM_new = SVC()
SVM_new.fit(X_train_new, y_train_new)

# create RF
RF_new = RandomForestClassifier(random_state = 1)
RF_new.fit(X_train_new,y_train_new)
# Train the models
# Out:
# RandomForestClassifier(random_state=1)

# %%
# Make predictions using the testing set
y_knn = KNN_new.predict(X_test_new)
y_dt = dt_new.predict(X_test_new)
y_svm = SVM_new.predict(X_test_new)
y_rf = RF_new.predict(X_test_new)

# %%
# calculate the metrics
acc1 = KNN_new.score(X_test_new, y_test_new)
acc2 = dt_new.score(X_test_new, y_test_new)
acc3 = SVM_new.score(X_test_new, y_test_new)
acc4 = RF_new.score(X_test_new, y_test_new)
print(acc1,'\n',acc2,'\n',acc3,'\n',acc4,'\n')
# Out:
# 0.914
#  0.82
#  0.94
#  0.86

# %%
# # construct the comparison table
data = {
    "Metric": ["Acc"],
    "KNN": [acc1],
    "Tree": [acc2],
    "SVM": [acc3],
     "RF": [acc4],
}

comparison = pd.DataFrame(data, columns=["Metric", "KNN", "Tree", "SVM", "RF"])
comparison
# Out:
#   Metric    KNN  Tree   SVM    RF
# 0    Acc  0.914  0.82  0.94  0.86

# %%
def plot_comparison(dataframe, title="Comparison", figsize=(15, 5)):
    """
    Plot bar plots with metric labels on top of each bar.
    """
    # Extract data from the DataFrame
    metrics = dataframe.columns[1:]
    #algorithm_values = dataframe.iloc[0, 1:].round(2)
    algorithm_values = dataframe.iloc[0, 1:]

    # Set the positions for the bars
    x = range(len(algorithm_values))

    # Plot the bar plot
    plt.figure(figsize=figsize)
    bars = plt.bar(x, algorithm_values, color=['tab:cyan', 'tab:cyan', 'tab:cyan'])  # Colors for KNN, Tree, SVM

    # Add metric labels on top of each bar
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

    # Add labels, title, and legend
    plt.xlabel('Algorithm')
    plt.ylabel('Accuracy')
    plt.title(title)
    plt.xticks(x, metrics)

    # Show plot
    plt.tight_layout()
    plt.show()

# %%
plot_comparison(comparison)

# %% [markdown]
# ### 3.2 Tran-Test split - Stratified
#
# Some classification problems do not have a balanced number of examples for each class label. As such, it is desirable to split the dataset into train and test sets in a way that preserves the same proportions of examples in each class as observed in the original dataset.
#
# This is called a stratified train-test split.
#
# Hint: use "stratify=y" in "train_test_split"

# %%
X_train_new1, X_test_new1, y_train_new1, y_test_new1 = train_test_split(X, y, random_state = 1, train_size = 0.75, stratify=y)
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %% [markdown]
# ### Train and calculate the accuracy for:
# - Decision Tree
# - KNN
# - SVM
# - Random Forest
#
# Present the accuracy in a Table and also in Bar Chart - you have the code below.

# %%
# Create KNN
KNN_new1 = KNeighborsClassifier(3)
KNN_new1.fit(X_train_new1, y_train_new1)
# create Decistion Tree
dt_new1 = DecisionTreeClassifier(max_depth = 5, random_state = 1)
dt_new1.fit(X_train_new1, y_train_new1)
# create SVM
SVM_new1 = SVC()
SVM_new1.fit(X_train_new1, y_train_new1)
# create RF
RF_new1 = RandomForestClassifier(random_state = 1)
RF_new1.fit(X_train_new1,y_train_new1)
# Train the models
# Out:
# RandomForestClassifier(random_state=1)

# %%
acc11 = KNN_new1.score(X_test_new1, y_test_new1)
acc22 = dt_new1.score(X_test_new1, y_test_new1)
acc33 = SVM_new1.score(X_test_new1, y_test_new1)
acc44 = RF_new1.score(X_test_new1, y_test_new1)
print(acc11,'\n',acc22,'\n',acc33,'\n',acc44)
# Out:
# 0.914
#  0.818
#  0.958
#  0.89

# %%
data = {
    "Metric": ["Acc"],
    "KNN": [acc11],
    "Tree": [acc22],
    "SVM": [acc33],
    "RF": [acc44],
}

comparison1 = pd.DataFrame(data, columns=["Metric", "KNN", "Tree", "SVM", "RF"])
comparison1
# Out:
#   Metric    KNN   Tree    SVM    RF
# 0    Acc  0.914  0.818  0.958  0.89

# %%
plot_comparison(comparison1)

# %% [markdown]
# ## 3.3 Cross Validation
#
# Train and Validate the Random Forest classifier with 10 FOLD Cross Valdiation randomized (shuffle).
# - Print the accuracy and the confusion matrix and classificaiton report
# - Hint - Use: KFold(n_splits=10, shuffle=True)
#
# More info:
# - https://scikit-learn.org/stable/modules/cross_validation.html
#
# Scoring metrics:
# - https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold

#train RF model
kf = KFold(n_splits=10, shuffle=True)
scores = cross_val_score(RF_new1, X, y, cv=kf, scoring="accuracy")
avg = np.mean(scores)

# %%
### print the avearage accuracy, and the accuracy for each fold
for fold, score in enumerate(scores):
    print("fold", fold, "accuracy:", score)
print("The average accuracy: ", avg)
# Out:
# fold 0 accuracy: 0.89
# fold 1 accuracy: 0.87
# fold 2 accuracy: 0.9
# fold 3 accuracy: 0.87
# fold 4 accuracy: 0.875
# fold 5 accuracy: 0.915
# fold 6 accuracy: 0.89
# fold 7 accuracy: 0.875
# fold 8 accuracy: 0.865
# fold 9 accuracy: 0.87
# The average accuracy:  0.882
