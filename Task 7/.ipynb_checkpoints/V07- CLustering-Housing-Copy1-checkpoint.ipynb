# %% [markdown]
# # Clustering- Housing
#
# https://scikit-learn.org/stable/datasets/real_world.html#california-housing-dataset
#
# This dataset was obtained from the StatLib repository. https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surprisingly large values for block groups with few households and many empty houses, such as vacation resorts.
#
# https://www.datacamp.com/tutorial/k-means-clustering-python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing
X, y = fetch_california_housing(return_X_y=True)

# %%
X = pd.DataFrame(data=X, columns= ["MedInc median income in block group", "HouseAge median house age in block group", "AveRooms average number of rooms per household", "AveBedrms average number of bedrooms per household", "Population block group population", "AveOccup average number of household members", "latitude", "longitude"])
y = pd.DataFrame(data=y, columns=["median_house_value"])
y.describe()
# Out:
#        median_house_value
# count        20640.000000
# mean             2.068558
# std              1.153956
# min              0.149990
# 25%              1.196000
# 50%              1.797000
# 75%              2.647250
# max              5.000010

# %% [markdown]
# We will take only the longitude and latitude for the clustering part.
#
# We will use the Median house value as a reference - but it does not influence the clustering

# %%
home_data = X[["latitude", "longitude"]]
home_data2 = pd.concat([home_data, y], axis=1)
home_data2.head()
# Out:
#    latitude  longitude  median_house_value
# 0     37.88    -122.23               4.526
# 1     37.86    -122.22               3.585
# 2     37.85    -122.24               3.521
# 3     37.85    -122.25               3.413
# 4     37.85    -122.25               3.422

# %% [markdown]
# ## Visualize the data
#
# We start by visualizing the location data with a heatmap based on the median price in a block. We will use Seaborn .
#
#
# We see that most of the expensive houses are on the west coast of California with different areas that have clusters of moderately priced houses. This is expected as typically waterfront properties are worth more than houses that are not on the coast.
#
# Clusters are often easy to spot when you are only using 2 or 3 features. It becomes increasingly difficult or impossible when the number of features increases.

# %%
import seaborn as sns

sns.scatterplot(data = home_data2, x = 'longitude', y = 'latitude', hue = 'median_house_value')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ## Normalize the data
#
# When working with distance-based algorithms, like k-Means Clustering, we must normalize the data.
# - If we do not normalize the data, variables with different scaling will be weighted differently in the distance formula that is being optimized during training. For example, if we were to include price in the cluster, in addition to latitude and longitude, price would have an outsized impact on the optimizations because its scale is significantly larger and wider than the bounded location variables.

# %%
from sklearn import preprocessing

home_data_norm = preprocessing.normalize(home_data)

# %% [markdown]
# ## KMEANS
#
# For the first iteration, we will arbitrarily choose a number of clusters (referred to as k) of 3.
# Building and fitting models in sklearn is very simple.
# - create an instance of KMeans,
# - define the number of clusters using the n_clusters attribute,
# - set n_init, which defines the number of iterations the algorithm will run with different centroid seeds, to “auto,” and
# - set the random_state to 0 so we get the same result each time we run the code.
#
# We can then fit the model to the normalized training data using the fit() method.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 3, random_state = 0, n_init='auto')
kmeans.fit(home_data_norm)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %% [markdown]
# Visualize the data using the labels from the KMeans algorithm.

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = kmeans.labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# We see that the data are now clearly split into 3 distinct groups (Northern California, Central California, and Southern California).
#
# We can also look at the distribution of median house prices in these 3 groups using a boxplot.
# - We clearly see that the Northern and Southern clusters have similar distributions of median house values (clusters 0 and 2) that are higher than the prices in the central cluster (cluster 1).

# %%
sns.boxplot(x = kmeans.labels_, y = y['median_house_value'])
# Out:
# <Axes: ylabel='median_house_value'>

# %% [markdown]
# ## Silhouette score
# We can evaluate performance of the clustering algorithm using a Silhouette score which is a part of sklearn.metrics where a lower score represents a better fit.

# %%
from sklearn.metrics import silhouette_score

silhouette_score(home_data_norm, kmeans.labels_, metric='euclidean')
# Out:
# 0.7499115323392395

# %% [markdown]
# ## Choosing the best number of clusters
#
# The weakness of k-means clustering is that we don’t know how many clusters we need by just running the model. We need to test ranges of values and make a decision on the best value of k. We typically make a decision using the Elbow method to determine the optimal number of clusters where we are both not overfitting the data with too many clusters, and also not underfitting with too few.
#
# We create the below loop to test and store different model results so that we can make a decision on the best number of clusters.

# %%
K = range(2, 8)
fits = []
score = []


for k in K:
    # train the model for current value of k on training data
    model = KMeans(n_clusters = k, random_state = 0, n_init='auto').fit(home_data_norm)
    
    # append the model to fits
    fits.append(model)
    
    # Append the silhouette score to scores
    score.append(silhouette_score(home_data_norm, model.labels_, metric='euclidean'))

# %% [markdown]
# We can then first visually look at a few different values of k.
#  - First we look at k = 2.
#  - k = 4
#  - k = 5
#  - k = 7

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = fits[0].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = fits[2].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = fits[3].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = fits[5].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# ## Elbow method
# Typically, as we increase the value of K, we see improvements in clusters and what they represent until a certain point. We then start to see diminishing returns or even worse performance. We can visually see this to help make a decision on the value of k by using an elbow plot where the y-axis is a measure of goodness of fit and the x-axis is the value of k.
#
# We typically choose the point where the improvements in performance start to flatten or get worse. We see k = 5 is probably the best we can do without overfitting.
#
# We can also see that the clusters do a relatively good job of breaking California into distinct clusters and these clusters map relatively well to different price ranges as seen below.

# %%
sns.lineplot(x = K, y = score)
# Out:
# D:\Programs\Anaconda\envs\ISGP\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Programs\Anaconda\envs\ISGP\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %%
sns.scatterplot(data = home_data, x = 'longitude', y = 'latitude', hue = fits[3].labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.boxplot(x = fits[3].labels_, y = y['median_house_value'])
# Out:
# <Axes: ylabel='median_house_value'>

# %% [markdown]
# ## What if we use 3 fetures for the clustering?

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 3, random_state = 0, n_init='auto')
kmeans.fit(home_data2)
sns.scatterplot(data = home_data2, x = 'longitude', y = 'latitude', hue = kmeans.labels_)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# # ToDo
#
# Use the same dataset with 2 features ("home_data") and apply:
# - Agglomerative Clustering
# - Gaussian Mixture clustering
# - DBSCAN
#
# Create a table with the results for the Silhouette_score for each of the Algorithms
# - Kmeans
# - Agglomerative Clustering
# - Gaussian Mixture clustering
# - DBSCAN

# %%
#KMeans

from sklearn.cluster import KMeans

KMC = KMeans(n_clusters=3, random_state=42, n_init=10)
KMC_labels = KMC.fit_predict(home_data)

plt.figure(figsize=(10, 6))
plt.scatter(home_data["longitude"], home_data["latitude"], c=KMC_labels, cmap='viridis', marker='o')
plt.title('KMeans Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
#Agglomerative Clustering

from sklearn.cluster import AgglomerativeClustering

AC = AgglomerativeClustering(n_clusters=3)
AC_labels = AC.fit_predict(home_data)

plt.figure(figsize=(10, 6))
plt.scatter(home_data["longitude"], home_data["latitude"], c=AC_labels, cmap='viridis', marker='o')
plt.title('Agglomerative Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
#Gaussian Mixture Clustering

from sklearn.mixture import GaussianMixture

GMC = GaussianMixture(n_components=3, random_state=42)
GMC_labels = GMC.fit_predict(home_data)

plt.figure(figsize=(10, 6))
plt.scatter(home_data["longitude"], home_data["latitude"], c=GMC_labels, cmap='viridis', marker='o')
plt.title('Gaussian Mixture Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
#DBSCAN Clustering

from sklearn.cluster import DBSCAN

DBC = DBSCAN(eps=0.1, min_samples=10)
DBC_labels = DBC.fit_predict(home_data)

plt.figure(figsize=(10, 6))
plt.scatter(home_data["longitude"], home_data["latitude"], c=DBC_labels, cmap='viridis', marker='o')
plt.title('DBSCAN Clustering')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
#Silhouette score

#Agglomerative Clustering Silhouette score:
AC_silhouette = silhouette_score(home_data, AC_labels)

#KMeans Clustering Silhouette score:
KMC_silhouette = silhouette_score(home_data, KMC_labels)

#Gaussian Mixture Clustering Silhouette score:
GMC_silhouette = silhouette_score(home_data, GMC_labels)

#DBSCAN Clustering Silhouette score:
if len(set(DBC_labels)) > 1:
    DBC_silhouette = silhouette_score(home_data, DBC_labels)
else:
    DBC_silhouette = -1  # Invalid score for DBSCAN if only 1 cluster

silhouette_scores = {
    "Algorithm": ["KMeans", "Agglomerative Clustering", "Gaussian Mixture", "DBSCAN"],
    "Silhouette Score": [KMC_silhouette, AC_silhouette, GMC_silhouette, DBC_silhouette]
}
results_df = pd.DataFrame(silhouette_scores)
results_df
# Out:
#                   Algorithm  Silhouette Score
# 0                    KMeans          0.647182
# 1  Agglomerative Clustering          0.629385
# 2          Gaussian Mixture          0.381915
# 3                    DBSCAN          0.148701
